# %%
import pandas as pd
import numpy as np
import pickle
from itertools import chain
# import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import time
import timeit
import csv
import os
import string
import textblob
import io

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn import preprocessing
from sklearn import decomposition, ensemble

from importlib import reload
# reload(text_processing)


# nlp = spacy.load('en') # loading the language model 
#data = pd.read_feather('data/preprocessed_data') # reading a pandas dataframe which is stored as a feather file


# %matplotlib inline
# sns.set_context('poster')
# sns.set_color_codes()
full_path_data_store = 'Data/'

# %% [markdown]
# ### Data
# - load data from file
# - eda/inspect data
# - assemble datasets for parity
# - merge with climate data

# %% [markdown]
# #### load data

# %%
def load_all_data(data_list,full_path_data_store=full_path_data_store):
    '''
    Args: 
    - data_list: list of dataframes to load
    - full_path_data_store: path to data
    Returns:
    Dictionary of dataframes by name
    '''
    df_datasets={}
    for df_name in data_list:
        print('loading {} data...'.format(df_name))
        df = pd.read_pickle(full_path_data_store + "{}.pkl".format(df_name)).drop_duplicates(subset='processed_text')
        df.name = df_name
        
        # clean climate docs of headers and footers
        if df_name == 'climate_':
            df['processed_text']=[i[515:-700].split(' ',2)[2].rsplit(' ',1)[0] for i in df.processed_text]
            df.name = df_name
        df_datasets[df_name]=df
    
    return df_datasets

# %%
data_list=['climate','eu', 'bbc','climate_bbc','eu_bbc','climate_science','eu_science', 'spam', 'newsgroups', 'reuters', 'science']

# %%
# load all data
df_datasets=load_all_data(data_list)
# Out:
# loading climate data...
# loading eu data...
# loading bbc data...
# loading climate_bbc data...
# loading eu_bbc data...
# loading spam data...
# loading newsgroups data...
# loading reuters data...
# loading science data...

# %% [markdown]
# #### eda

# %%
def get_doc_counts(df):
    """
    Args:
        df: a data frame
    Returns:
        a list of length counts for each doc
    """
    
    return [len(i) for i in df.processed_text]

# %%
def count_zero_lens(df):
    """
    Args:
        df: a data frame
    Returns:
        a list of zero counts for each doc 
    """
    
    count=0
    for i in df.processed_text:
        if len(i) == 0:
            count+=1
    return count

# %%
def get_df_stats(df_dict, record_=True, print_=True):
    
    """
    Args:
        df_dict: dict of dataframe objects
    Returns:
    - Option: 'print_' boolean, returns a dataframe of stats for data 
    - Option: 'record_' boolean, saves stats to csv
    """
    
    columns=['total_docs','dups','zero_vals','vocab_raw','vocab_proc','min_doc_len','max_doc_len','mean_len','std']
    temp_dict={}
    for k,v in df_dict.items():
        row=[]
        cv = CountVectorizer()
        cvu = CountVectorizer()
        cvu.fit(v.processed_text)
        cv.fit(v.texts)
        vdc = get_doc_counts(v)
        row.append([
                    len(vdc),
                   len(v.processed_text)-len(v.processed_text.unique()),
                   count_zero_lens(v),
                   len(cv.vocabulary_),
                   len(cvu.vocabulary_),
                   min(vdc),
                    max(vdc),
                   int(np.mean(vdc)),
                   int(np.std(vdc))
                   ])
        temp_dict[k]=row[0]
    
    df=pd.DataFrame(temp_dict).T
    df.columns=columns
    
    if record_:
        df.reset_index(drop=True)
        time_=time.strftime("%a_%d_%b_%Y_%H:%M:%S", time.gmtime())
        df.to_csv('Output/DF_analysis/df_stats_{}.csv'.format(time_))
    
    if print_:
        return df
    return df

# %%
def plot_classes(df_dict):
    """
    Plots histogram of classes in dataset 
    
    Args:
        df_dict: dict of dataframes
    returns:
        None
    """
    
    time_=time.strftime("%a_%d_%b_%Y_%H:%M:%S", time.gmtime())
    encoder = preprocessing.LabelEncoder()
    result_dict={}
    classes={}
    for k,v in df_dict.items():
        result_dict[k] = v.labels.value_counts()
        classes[k]= np.unique(encoder.fit_transform(v.labels))
    fig, axs = plt.subplots(1, len(result_dict), figsize=(15, 2), sharey=True,sharex=False)
    fig.suptitle('Distribution of Unique Classes (chars)')
    for idx,kv in enumerate(result_dict.items()):
        axs[idx].bar(classes[kv[0]],height=kv[1])
        axs[idx].set_xlabel(kv[0])
    plt.savefig('Output/DF_analysis/all_dfs_classes_histograms_{}.png'.format(time_))

# %%
import matplotlib.pyplot as plt
% matplotlib inline
# slice docs in climate data to get meat
# make mask based on min/max length of merged dataset 

def plot_doc_lengths(df_dict):
    """
    Plots histogram of length of docs in dataset
    
    Args:
        df_dict
    Return:
        None
    """
    
    result_dict={}
    for k,v in df_dict.items():
        result_dict[k] = get_doc_counts(v)
    fig, axs = plt.subplots(1, len(result_dict), figsize=(15, 2), sharey=False,sharex=False)
    fig.suptitle('Distribution of Document Lengths (chars)')
    for idx,kv in enumerate(result_dict.items()):
        axs[idx].hist(kv[1])
        #axs[1,idx].boxplot(kv[1].get('count'))
        axs[idx].set_xlabel(kv[0])
    time_=time.strftime("%a_%d_%b_%Y_%H:%M:%S", time.gmtime())
    plt.savefig('Output/DF_analysis/all_dfs_distributions_{}.png'.format(time_))

# %%
get_df_stats(df_datasets)
# Out:
#              total_docs  dups  zero_vals  vocab_raw  vocab_proc  min_doc_len  \
# climate            2745     0          1      13453        8652            0
# eu                 1250     0          0       8590        5970            7
# bbc                2114     0          1      29418       21626            0
# climate_bbc        4223     0          0      34359       25074           85
# eu_bbc             1842     0          0      25149       18331           67
# spam               4889     0          1       8633        5782            0
# newsgroups        10711     0          0      98439       55269           56
# reuters           10530     0          1      30913       21761            0
# science            5735     0          0      42109       29684           47
#
#              max_doc_len  mean_len   std
# climate             6901       672   531
# eu                  2680       291   311
# bbc                12948      1290   731
# climate_bbc         8814       949   662
# eu_bbc              8814       790   671
# spam                 361        35    27
# newsgroups         40834       873  1723
# reuters             5610       474   505
# science             2649       922   302

# %%
plot_classes(df_datasets)
plot_doc_lengths(df_datasets)

# %% [markdown]
# #### clip doc lengths (optional)
# - unhash below to clip

# %%
def clip_doc_lengths(df_dict,max_len=10000,min_len=100):
    """
    Args:
        df_dict: dict dataframe object
        max_len: sets maximum length for doc
        min_len: sets minimum length for doc
    Returns:
        dict dataframe object
    """
    for df_name,df in df_dict.items():
        
        if df_name != 'spam':
            df_name=df.name
            df['len_counts']=get_doc_counts(df)
            mean_=df['len_counts'].mean()
            df=df[(df.len_counts<=max_len)&(df.len_counts>=min_len)]
            df=df.drop(['len_counts'],axis=1)
        df.name=df_name
        df_dict[df_name]=df
    return df_dict

df_datasets_clipped=clip_doc_lengths(df_datasets)

# %%
plot_doc_lengths(df_datasets_clipped)

# %%
get_df_stats(df_datasets_clipped)
# Out:
#              total_docs  dups  zero_vals  vocab_raw  vocab_proc  min_doc_len  \
# climate            2685     0          0      13438        8651          100
# eu                  921     0          0       8408        5836          100
# bbc                2112     0          0      29342       21576          283
# climate_bbc        4217     0          0      34358       25073          101
# eu_bbc             1810     0          0      25136       18322          100
# spam               4889     0          1       8633        5782            0
# newsgroups        10612     0          0      91637       50824          100
# reuters            9112     0          0      30103       21423          100
# science            5733     0          0      42109       29684          109
#
#              max_doc_len  mean_len  std
# climate             6901       686  529
# eu                  2680       372  326
# bbc                 9478      1285  685
# climate_bbc         8814       951  662
# eu_bbc              8814       802  671
# spam                 361        35   27
# newsgroups          9985       768  847
# reuters             5610       537  516
# science             2649       922  302

# %% [markdown]
# #### remove over-represented words

# %%
def get_top_word_freqs(df_dict,n=10):
    time_=time.strftime("%a_%d_%b_%Y_%H:%M:%S", time.gmtime())
    temp_dict={}
    for k,v in df_dict.items():
        temp_dict[k]=v.processed_text.str.split(expand=True).stack().value_counts().head(10)
    df=pd.DataFrame(temp_dict)
    df.to_csv("Output/DF_analysis/top_word_frequencies_{}.csv".format(time_))
    return df

# %%
df_word_freqs=get_top_word_freqs(df_datasets_clipped)
df_word_freqs
# Out:
#               climate      eu     bbc  climate_bbc  eu_bbc   spam  newsgroups  \
# analysis          NaN     NaN     NaN          NaN     NaN    NaN         NaN
# article           NaN     NaN     NaN          NaN     NaN    NaN      7247.0
# billion           NaN     NaN     NaN          NaN     NaN    NaN         NaN
# building       1388.0   307.0     NaN          NaN     NaN    NaN         NaN
# cell              NaN     NaN     NaN          NaN     NaN    NaN         NaN
# come              NaN     NaN  1140.0          NaN   499.0  291.0         NaN
# company           NaN     NaN     NaN       1528.0   527.0    NaN         NaN
# control           NaN     NaN     NaN          NaN     NaN    NaN         NaN
# ct                NaN     NaN     NaN          NaN     NaN    NaN         NaN
# day               NaN     NaN     NaN          NaN     NaN  218.0         NaN
# dlrs              NaN     NaN     NaN          NaN     NaN    NaN         NaN
# efficiency     1989.0   353.0     NaN          NaN     NaN    NaN         NaN
# electricity    1455.0     NaN     NaN          NaN     NaN    NaN         NaN
# emission       2320.0   382.0     NaN          NaN     NaN    NaN         NaN
# energy         8989.0  1196.0     NaN          NaN     NaN    NaN         NaN
# expression        NaN     NaN     NaN          NaN     NaN    NaN         NaN
# film              NaN     NaN     NaN          NaN   511.0    NaN         NaN
# free              NaN     NaN     NaN          NaN     NaN  220.0         NaN
# game              NaN     NaN  1384.0          NaN   587.0    NaN         NaN
# gas               NaN   262.0     NaN          NaN     NaN    NaN         NaN
# gene              NaN     NaN     NaN          NaN     NaN    NaN         NaN
# get               NaN     NaN     NaN          NaN     NaN  292.0         NaN
# go                NaN     NaN     NaN          NaN     NaN  248.0         NaN
# good              NaN     NaN  1725.0          NaN     NaN  276.0      5700.0
# government     1580.0     NaN     NaN       2378.0   583.0    NaN         NaN
# high              NaN     NaN     NaN          NaN     NaN    NaN         NaN
# include        1471.0     NaN     NaN       2001.0     NaN    NaN         NaN
# know              NaN     NaN     NaN          NaN     NaN  260.0      5681.0
# line              NaN     NaN     NaN          NaN     NaN    NaN     10727.0
# measure           NaN   478.0     NaN          NaN     NaN    NaN         NaN
# mln               NaN     NaN     NaN          NaN     NaN    NaN         NaN
# net               NaN     NaN     NaN          NaN     NaN    NaN         NaN
# new            1786.0     NaN  1867.0          NaN     NaN    NaN         NaN
# organization      NaN     NaN     NaN          NaN     NaN    NaN     10619.0
# patient           NaN     NaN     NaN          NaN     NaN    NaN         NaN
# pct               NaN     NaN     NaN          NaN     NaN    NaN         NaN
# people            NaN     NaN  1860.0          NaN     NaN    NaN      5425.0
# plan              NaN     NaN     NaN       1814.0   553.0    NaN         NaN
# programme      1504.0     NaN     NaN       1510.0     NaN    NaN         NaN
# renewable      1873.0     NaN     NaN          NaN     NaN    NaN         NaN
# result            NaN     NaN     NaN          NaN     NaN    NaN         NaN
# say               NaN     NaN  7823.0          NaN     NaN    NaN         NaN
# send              NaN     NaN     NaN          NaN     NaN  230.0         NaN
# share             NaN     NaN     NaN          NaN     NaN    NaN         NaN
# study             NaN     NaN     NaN          NaN     NaN    NaN         NaN
# subject           NaN     NaN     NaN          NaN     NaN    NaN     11303.0
# support           NaN   251.0     NaN          NaN     NaN    NaN         NaN
# system            NaN     NaN     NaN       1474.0     NaN    NaN         NaN
# technology        NaN     NaN     NaN       1560.0     NaN    NaN         NaN
# think             NaN     NaN     NaN          NaN     NaN    NaN      5196.0
# time              NaN     NaN  1472.0       1617.0   675.0  223.0         NaN
# transport         NaN   284.0     NaN          NaN     NaN    NaN         NaN
# university        NaN     NaN     NaN          NaN     NaN    NaN      5087.0
# use               NaN   282.0     NaN       1538.0   547.0    NaN         NaN
# want              NaN     NaN     NaN          NaN     NaN  233.0         NaN
# waste             NaN   288.0     NaN          NaN     NaN    NaN         NaN
# win               NaN     NaN  1417.0       1427.0   575.0    NaN         NaN
# world             NaN     NaN  1171.0          NaN   559.0    NaN         NaN
# write             NaN     NaN     NaN          NaN     NaN    NaN      9392.0
# year              NaN     NaN  2832.0          NaN     NaN    NaN         NaN
#
#               reuters  science
# analysis          NaN   2612.0
# article           NaN      NaN
# billion        5651.0      NaN
# building          NaN      NaN
# cell              NaN   5221.0
# come              NaN      NaN
# company        5456.0      NaN
# control           NaN   2988.0
# ct             5599.0      NaN
# day               NaN      NaN
# dlrs           9961.0      NaN
# efficiency        NaN      NaN
# electricity       NaN      NaN
# emission          NaN      NaN
# energy            NaN      NaN
# expression        NaN   3588.0
# film              NaN      NaN
# free              NaN      NaN
# game              NaN      NaN
# gas               NaN      NaN
# gene              NaN   3103.0
# get               NaN      NaN
# go                NaN      NaN
# good              NaN      NaN
# government        NaN      NaN
# high              NaN   3043.0
# include           NaN      NaN
# know              NaN      NaN
# line              NaN      NaN
# measure           NaN      NaN
# mln           16989.0      NaN
# net            5576.0      NaN
# new               NaN      NaN
# organization      NaN      NaN
# patient           NaN   2773.0
# pct            9467.0      NaN
# people            NaN      NaN
# plan              NaN      NaN
# programme         NaN      NaN
# renewable         NaN      NaN
# result            NaN   4044.0
# say           25829.0      NaN
# send              NaN      NaN
# share          5675.0      NaN
# study             NaN   4958.0
# subject           NaN      NaN
# support           NaN      NaN
# system            NaN   2615.0
# technology        NaN      NaN
# think             NaN      NaN
# time              NaN      NaN
# transport         NaN      NaN
# university        NaN      NaN
# use               NaN      NaN
# want              NaN      NaN
# waste             NaN      NaN
# win               NaN      NaN
# world             NaN      NaN
# write             NaN      NaN
# year           7994.0      NaN

# %%
def get_freq_words(df_dict, n=15,cut_n=5, plot_=True):
    
    """
    Args
        df_dict: dict of dataframes
        n: number of most frequent words to select from dataframe
        plot_: boolean, show plot of results
    Return
        dictionary of most frequent words for each dataframe 
    """
    
    fig, axs = plt.subplots(1, len(df_dict), figsize=(15, 2), sharey=False,sharex=False)
    fig.suptitle('{} Frequent Words by Dataset'.format(n))
    
    words_cut={}
    for i,kv in enumerate(df_dict.items()):
        
        idx = kv[1].processed_text.str.split(expand=True).stack().value_counts().index
        vals = kv[1].processed_text.str.split(expand=True).stack().value_counts()
        df = pd.DataFrame({'idx':idx, 'vals':vals})
    
        if plot_:
            sns.set_palette("Paired")
            g=sns.barplot(x="idx", y="vals", data=df.head(15),ax=axs[i]).set_xticklabels(labels=df.idx,rotation=75)
            axs[i].set_xlabel(kv[0])
            time_=time.strftime("%a_%d_%b_%Y_%H:%M:%S", time.gmtime())
            plt.savefig('Output/DF_analysis/distribution_of_{}_frequent_words_{}.png'.format(n,time_))
        
        words_cut[kv[0]]=list(df.head(cut_n).idx)
        
    return words_cut

# %%
def remove_freq_words(df_dict,freq_list):
    """
    Arg
        df_dict: a dict of dataframes
        freq_list: dict of lists, keys are df_names
    Return
        dict of dataframes
    """
    
    for df_name,word_lst in freq_list.items():
        for word in word_lst:
            df_dict[df_name].processed_text=df_dict[df_name].processed_text.str.replace(word+" ","")
    return df_dict

# %%
# get frequent words
freq_words=get_freq_words(df_datasets_clipped)

# %%
# remove frequent words
df_datasets=remove_freq_words(df_datasets_clipped,freq_words)

# %%
# display results
freq_words_=get_freq_words(df_datasets_clipped)

# %% [markdown]
# ### Split & Merge for Training and Testing
# - Merge Climate + BBC (train)
# - Merge EU + BBC (test)

# %%
df_data={}
df_data['climate']=df_datasets['climate']
df_data['eu']=df_datasets['eu']
df_data['bbc']=df_datasets['bbc']
df_data['science']=df_datasets['science']
get_freq_words(df_data)
get_df_stats(df_data)
# Out:
#          total_docs  dups  zero_vals  vocab_raw  vocab_proc  min_doc_len  \
# climate        2685     0          0      13438        8708           85
# eu              921     0          0       8408        5836           67
# bbc            2112     1          0      29342       21603          283
# science        5733     0          0      42109       29904          109
#
#          max_doc_len  mean_len  std
# climate         6550       637  490
# eu              2510       349  308
# bbc             8814      1250  665
# science         2586       897  292

# %%
def merge_df(target_df,other_df,name_of_new_df):
    '''
    Args: 
    - target_df: name of df e.g. 'climate'
    - df_other: a pd.dataframe with columns: 'texts','labels','processed_text'
    name_of_new-df: a string
    Returns: 
    - a dataframe with climate and random sample of other data 50/50 split,
        '1' = 'climate' '0' = 'other label'
    Note: uncomment other labels
    '''
    
    df = target_df
    length = min(df.shape[0],other_df.shape[0])
    other_s = other_df.sample(length)
    other_s.labels = 0
    df_s = df.sample(length)
    df_os = other_s.append(df_s,sort=False)
    df_os.name=name_of_new_df
    time_=time.strftime("%a_%d_%b_%Y_%H:%M:%S", time.gmtime())
    df_os.to_pickle(full_path_data_store + "{}.pkl".format(name_of_new_df))
    
    return df_os

# %%
# merge climate with other dataset and add to dataframe dict

def merge_to_data_dict(name_primary_df, name_other_df,name_mgd_df):
    """
    Merges and adds dataframe to data dict
    Args
        name_primary_df name of first df
        name_other_df: name of second df
        name_mgd_df: name of merged df
    Return
        None
    """
    df_datasets[name_mgd_df]=merge_df(df_datasets[name_primary_df],df_datasets[name_other_df],name_mgd_df)
    
    
# merge climate and bbc
merge_to_data_dict('climate','bbc','climate_bbc')
get_df_stats(df_datasets).loc[['climate_bbc'],:]
# Out:
# 2112
#              total_docs  dups  zero_vals  vocab_raw  vocab_proc  min_doc_len  \
# climate_bbc        4224     1          0      34359       25074           85
#
#              max_doc_len  mean_len  std
# climate_bbc         8814       950  662

# %%
# merge eu and bbc
merge_to_data_dict('eu','bbc','eu_bbc')
get_df_stats(df_datasets).loc[['eu_bbc'],:]
# Out:
# 921
#         total_docs  dups  zero_vals  vocab_raw  vocab_proc  min_doc_len  \
# eu_bbc        1842     0          0      25149       18331           67
#
#         max_doc_len  mean_len  std
# eu_bbc         8814       790  671

# %%
# merge climate and science
merge_to_data_dict('climate','science','climate_science')
get_df_stats(df_datasets).loc[['climate_science'],:]
# Out:
# 2685
#                  total_docs  dups  zero_vals  vocab_raw  vocab_proc  \
# climate_science        5370     0          0      34568       24323
#
#                  min_doc_len  max_doc_len  mean_len  std
# climate_science           85         6550       770  425

# %%
# merge eu and science
merge_to_data_dict('eu','science','eu_science')
get_df_stats(df_datasets).loc[['eu_science'],:]
# Out:
# 921
#             total_docs  dups  zero_vals  vocab_raw  vocab_proc  min_doc_len  \
# eu_science        1842     0          0      20857       14791           67
#
#             max_doc_len  mean_len  std
# eu_science         2510       621  403

# %%
df_data={}
df_data['climate_bbc']=df_datasets['climate_bbc']
df_data['eu_bbc']=df_datasets['eu_bbc']
df_data['climate_science']=df_datasets['climate_science']
df_data['eu_science']=df_datasets['eu_science']
get_top_word_freqs(df_data)
# Out:
#              climate_bbc  eu_bbc  climate_science  eu_science
# child                NaN     NaN              NaN       412.0
# come                 NaN   499.0              NaN         NaN
# company           1528.0   527.0              NaN         NaN
# control              NaN     NaN              NaN       488.0
# development          NaN     NaN           1689.0         NaN
# electricity          NaN     NaN           1831.0         NaN
# film                 NaN   510.0              NaN         NaN
# game              1385.0     NaN              NaN         NaN
# high                 NaN     NaN           1799.0       537.0
# include              NaN   497.0           2228.0       463.0
# increase             NaN     NaN           1788.0       575.0
# level                NaN     NaN           1793.0       466.0
# method               NaN     NaN              NaN       498.0
# patient              NaN     NaN              NaN       411.0
# plan                 NaN   553.0              NaN         NaN
# play                 NaN   492.0              NaN         NaN
# power                NaN     NaN           1723.0         NaN
# programme         1509.0     NaN              NaN         NaN
# project           1344.0     NaN              NaN         NaN
# provide              NaN     NaN           1781.0         NaN
# service              NaN   462.0              NaN         NaN
# set               1337.0   463.0              NaN         NaN
# system            1473.0     NaN           2508.0       585.0
# tax               1356.0     NaN              NaN         NaN
# use               1538.0   546.0           1783.0       476.0
# win               1427.0     NaN              NaN         NaN
# work              1336.0   480.0              NaN         NaN

# %%
# add everything to df_datasets and pickle 

with open('../Data/'+'df_datasets.pickle', 'wb') as handle:
    pickle.dump(df_datasets, handle, protocol=pickle.HIGHEST_PROTOCOL)
