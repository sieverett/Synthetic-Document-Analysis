# %%
#import libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from requests import get
import json

import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import asyncio
import concurrent.futures
import re
import os
import nltk
from textblob import Word
from nltk.tag import pos_tag
from nltk.corpus import reuters
from nltk.corpus import stopwords
from nltk import download as nltk_download
from nltk.stem.snowball import SnowballStemmer
from sklearn.model_selection import train_test_split
from sklearn.datasets.twenty_newsgroups import fetch_20newsgroups
""
stemmer = SnowballStemmer("english")
stop_words=stopwords.words('english')

session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# %% [markdown]
# ## IEA Data

# %%
#get all countries with entiries in the IEA database
get_countries = "https://www.iea.org/policiesandmeasures/climatechange/"
g_c = get(get_countries)

soup_c = BeautifulSoup(g_c.text, 'html.parser')
c_list = soup_c.find("ul", class_ ="listexpander")
c_loop = c_list.find_all("label")

country_store = []
for c in c_loop:
    country_store.append(c.text)
    
full_list = country_store[4:]
print(full_list)
# Out:
# ['Albania', 'Algeria', 'Australia', 'Austria', 'Belgium', 'Bosnia and Herzegovina', 'Brazil', 'Canada', 'China', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia', 'European Union', 'Finland', 'France', 'Germany', 'Ghana', 'Greece', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy', 'Japan', 'Korea', 'Latvia', 'Luxembourg', 'Malaysia', 'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'Slovak Republic', 'South Africa', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom', 'United States']

# %%
#get each countries directory of database entries for climate policies and measure, renewable energy, 
#and energy efficiency

def get_countries(link_store, url):
    for country in full_list:
        if " " in country:
            amend = country.replace(" ", "%20")
            policy_link = url + amend 
            link_store.append(policy_link)
        else:
            policy_link = url + country
            link_store.append(policy_link)
        
#for climate policies and measure database
policy_link_store = []
get_countries(policy_link_store, "https://www.iea.org/policiesandmeasures/climatechange/?country=")
print(len(policy_link_store))
# Out:
# 51

# %%
#for renewable energy
renewables_store = []
get_countries(renewables_store, "https://www.iea.org/policiesandmeasures/renewableenergy/?country=")
print(len(renewables_store))
# Out:
# 51

# %%
#energy efficiency
efficiency_store = []
get_countries(efficiency_store, "https://www.iea.org/policiesandmeasures/energyefficiency/?country=")
print(len(efficiency_store))
# Out:
# 51

# %%
#get individual links for each entry in db

def store_pages(store, ptype):
    for p in ptype:
        g_p = session.get(p)
        soup_p = BeautifulSoup(g_p.text, 'html.parser')
        entries = soup_p.find_all("tr")[1:]
        for entry in entries:
            ext = entry.find("a", href = True)
            link = "https://www.iea.org/" + ext._attr_value_as_string("href")
            store.append(link)

# %%
#get individual links for each policy and measure page for each country          
page_link_store = []
store_pages(page_link_store, policy_link_store) 
print(len(page_link_store))
# Out:
# 2790

# %%
#get individual links for each renewable energy policy for each country 
renewpage_link_store = []
store_pages(renewpage_link_store,renewables_store)
print(len(renewpage_link_store))
# Out:
# 1492

# %%
#get individual links for each energy efficiency policy for each country 
eff_page_link_store = []
store_pages(eff_page_link_store, efficiency_store)
print(len(eff_page_link_store))
# Out:
# 1492

# %%
#Scrape each climate policy webpage in db
full_set = []

async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in page_link_store
        ]
        
        for response in await asyncio.gather(*futures):
            soup_e = BeautifulSoup(response.text, 'html.parser')

            table = soup_e.find("tbody").find_all("td")

            entry = dict()
            for i in range(len(table)):

                
                if "Policy Type" in table[i].text:
                    entry[table[i].text.lower()] = table[i+1].text.lower()

                elif "Description" in table[i].text:
                    entry[table[i].text.lower()] = table[i+1].text.lower()

            full_set.append(entry)



loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
len(full_set)
# Out:
# 2790

# %%
#Scrape each renewable energy policy webpage in db


async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in renewpage_link_store
        ]
        
        for response in await asyncio.gather(*futures):
            soup_e = BeautifulSoup(response.text, 'html.parser')

            table = soup_e.find("tbody").find_all("td")

            entry = dict()
            for i in range(len(table)):

    
                if "Policy Type" in table[i].text:
                    entry[table[i].text.lower()] = table[i+1].text.lower()

                elif "Description" in table[i].text:
                    entry[table[i].text.lower()] = table[i+1].text.lower()

            full_set.append(entry)


loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
len(full_set)
# Out:
# 4282

# %%
#Scrape each energy efficiency policy webpage in db


async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in eff_page_link_store
        ]
        
        for response in await asyncio.gather(*futures):
            soup_e = BeautifulSoup(response.text, 'html.parser')

            table = soup_e.find("tbody").find_all("td")

            entry = dict()
            for i in range(len(table)):

     
                if "Policy Type" in table[i].text:
                    entry[table[i].text.lower()] = table[i+1].text.lower()

                elif "Description" in table[i].text:
                    entry[table[i].text.lower()] = table[i+1].text.lower()

            full_set.append(entry)


loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
len(full_set)
# Out:
# 6277

# %%
print('climate change policy db:', len(page_link_store))
print('renewable energy policy db:', len(renewpage_link_store))
print('energy efficiency db:', len(eff_page_link_store))

print('total:', len(full_set))
# Out:
# climate change policy db: 2790
# renewable energy policy db: 1492
# energy efficiency db: 1995
# total: 6277

# %%
with open('iea_separate.json', 'w') as outfile:
    json.dump(full_set, outfile)

# %%
load = pd.read_json('iea_separate.json', 'column')
fixed = load.drop(load.columns[2:4], axis=1)
fixed['label'] = 1
fixed
# Out:
#                                            description:  \
# 0     the 21st session of the conference of the part...
# 1     the main goal of the albanian national strateg...
# 2     the carbon farming initiative (cfi) was a volu...
# 3     climate action 21 sets the tasmanian governmen...
# 4     the $5 million solar communities program will ...
# 5     the queensland government, in partnership with...
# 6     develop a formal government strategy and imple...
# 7     the clean energy finance corporation (cefc) wa...
# 8     in line with the government's commitment to re...
# 9     australia’s post-2020 emission reduction targe...
# 10    the 21st session of the conference of the part...
# 11    the queensland government is investing $3 mill...
# 12    the reef 2050 plan was released by the austral...
# 13    the share initiative is the first stage in are...
# 14     \nthe research and development (r&d) programm...
# 15    the objective of the emissions reduction fund ...
# 16    the australian government will work with the c...
# 17    yourenergysavings.gov.au is the place to go to...
# 18    the regional australia’s renewables (rar) init...
# 19    the previous australian government introduced ...
# 20    the objective of the coal mining abatement tec...
# 21    the jobs and competitiveness program provided ...
# 22    the previous government's clean energy future ...
# 23    the coal sector jobs package (csjp) provides t...
# 24    the aud800 million clean technology investment...
# 25    the local government energy efficiency program...
# 26    the clean technology innovation programme prov...
# 27    the industrial energy efficiency data analysis...
# 28    the australian government announced its intent...
# 29    arena’s up to $60 million renewable energy ven...
# ...                                                 ...
# 6247  heat islands are a phenomena where urban and s...
# 6248  part of the energy star program, this initiati...
# 6249  the state energy program (sep) provides grants...
# 6250  the directory provides information on building...
# 6251  native american housing block grants provide f...
# 6252  the u.s. treasury departments residential ener...
# 6253  energy star certified new homes meet strict gu...
# 6254  the federal utility partnership working group ...
# 6255  clean cities is a government-industry partners...
# 6256  the environmentally preferable purchasing (epp...
# 6257  energy star for industry is a voluntary u.s. e...
# 6258  energy star commercial buildings is a voluntar...
# 6259  the building energy codes program (becp) missi...
# 6260  under the energy policy act of 1992 state and ...
# 6261  energy efficient mortgages (eems) can be used ...
# 6262  the vehicle technologies office aims to develo...
# 6263  energy star products must meet certain minimum...
# 6264  energy savings performance contracts (espcs) w...
# 6265  the national industrial competitiveness throug...
# 6266  this department of energy (doe)-managed progra...
# 6267  liheap is a federally funded block grant progr...
# 6268  the low income home energy assistance program ...
# 6269  purpa created a market for power from non-util...
# 6270  the department of energys federal energy manag...
# 6271  the weatherization assistance program (wap) en...
# 6272  the weatherization and intergovernmental progr...
# 6273  industrial assessment centers (iacs) provide e...
# 6274  the advanced manufacturing office [formerly in...
# 6275  corporate average fuel economy (cafe) is the r...
# 6276  bestpractices, under the industrial technologi...
#
#                                            policy type:  label
# 0                     policy support>strategic planning      1
# 1                     policy support>strategic planning      1
# 2     economic instruments>market-based instruments>...      1
# 3     policy support>strategic planning, information...      1
# 4     economic instruments>fiscal/financial incentiv...      1
# 5     economic instruments>fiscal/financial incentiv...      1
# 6     regulatory instruments>codes and standards, re...      1
# 7     economic instruments>fiscal/financial incentiv...      1
# 8            regulatory instruments>codes and standards      1
# 9                     policy support>strategic planning      1
# 10                    policy support>strategic planning      1
# 11                            information and education      1
# 12                    policy support>strategic planning      1
# 13    research, development and deployment (rd&d;), ...      1
# 14         research, development and deployment (rd&d;)      1
# 15    policy support, economic instruments>market-ba...      1
# 16    economic instruments>fiscal/financial incentiv...      1
# 17      information and education>information provision      1
# 18         research, development and deployment (rd&d;)      1
# 19    economic instruments>fiscal/financial incentiv...      1
# 20    economic instruments>fiscal/financial incentiv...      1
# 21    economic instruments>direct investment, econom...      1
# 22    research, development and deployment (rd&d;), ...      1
# 23               economic instruments>direct investment      1
# 24    economic instruments>fiscal/financial incentiv...      1
# 25    economic instruments>fiscal/financial incentiv...      1
# 26    research, development and deployment (rd&d;)>r...      1
# 27                                       policy support      1
# 28    economic instruments>market-based instruments>...      1
# 29    voluntary approaches>negotiated agreements (pu...      1
# ...                                                 ...    ...
# 6247  voluntary approaches>negotiated agreements (pu...      1
# 6248  information and education>information provisio...      1
# 6249  economic instruments>fiscal/financial incentiv...      1
# 6250  information and education>information provisio...      1
# 6251  economic instruments>fiscal/financial incentiv...      1
# 6252  economic instruments>fiscal/financial incentiv...      1
# 6253  voluntary approaches, information and educatio...      1
# 6254    information and education>information provision      1
# 6255  voluntary approaches>negotiated agreements (pu...      1
# 6256  economic instruments>direct investment>procure...      1
# 6257  voluntary approaches>negotiated agreements (pu...      1
# 6258  voluntary approaches>negotiated agreements (pu...      1
# 6259  regulatory instruments, information and educat...      1
# 6260  economic instruments>direct investment>procure...      1
# 6261  economic instruments>fiscal/financial incentiv...      1
# 6262  research, development and deployment (rd&d;)>r...      1
# 6263  voluntary approaches>negotiated agreements (pu...      1
# 6264  economic instruments>direct investment>procure...      1
# 6265  economic instruments>fiscal/financial incentiv...      1
# 6266         regulatory instruments>codes and standards      1
# 6267  economic instruments>fiscal/financial incentiv...      1
# 6268  economic instruments>direct investment>funds t...      1
# 6269  economic instruments, economic instruments>mar...      1
# 6270  economic instruments>direct investment>procure...      1
# 6271  economic instruments>fiscal/financial incentiv...      1
# 6272  research, development and deployment (rd&d;)>r...      1
# 6273  information and education>advice/aid in implem...      1
# 6274  research, development and deployment (rd&d;)>r...      1
# 6275  regulatory instruments>codes and standards, re...      1
# 6276  information and education>information provisio...      1
#
# [6277 rows x 3 columns]

# %% [markdown]
# ## EU Climate Change Mitigation Policies and Measures Dataset

# %%
#load data
eu_db = pd.read_csv('EU_climate_change_mitigation_policies_and_measures.csv')

# %%
eu_db.head()
# Out:
#             _id:text    Country:text  ID_of_policy_or_measure:text  \
# 0  Czech Republic_21  Czech Republic                            21
# 1  Czech Republic_24  Czech Republic                            24
# 2         Romania_67         Romania                            67
# 3         Romania_38         Romania                            38
# 4        Belgium_115         Belgium                           115
#
#                       Name_of_policy_or_measure:text  \
# 0                    Combined transportation support
# 1                         Eco-labelling in transport
# 2                WEM Scenario for Agriculture sector
# 3            Modernization of the residential sector
# 4  Create economic conditions favourable to RES d...
#
#   Single_policy_or_measure__or_group_of_measures:text  \
# 0                                             Single
# 1                                             Single
# 2                                              Group
# 3                                             Single
# 4                                              Group
#
#   Policies_or_measures_included_in_the_group:text  \
# 0                                      Single PaM
# 1                                      Single PaM
# 2                    1, 5, 45, 46, 47, 48, 49, 50
# 3                                      Single PaM
# 4                                            2, 3
#
#   Type_of_policy_instrument:text Status_of_implementation:text  \
# 0                       Planning                   Implemented
# 1                    Information                   Implemented
# 2           Regulatory, Economic           See individual PaMs
# 3           Planning, Regulatory                       Planned
# 4                         Fiscal           See individual PaMs
#
#   Impact_of_policy_or_measure___EU_ETS__outside_the_ETS___ESD___or_LULUCF_:text  \
# 0                                                ESD
# 1                                                ESD
# 2                                        EU ETS, ESD
# 3                                                ESD
# 4                                             EU ETS
#
#       Sector_s__affected:text                  ...                   \
# 0                   Transport                  ...
# 1                   Transport                  ...
# 2  Cross-cutting, Agriculture                  ...
# 3          Energy Consumption                  ...
# 4               Energy Supply                  ...
#
#   Reference_for_realised_costs_and_benefits:text  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Web_link_for_realised_costs_and_benefits:text  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                        ReportID:text  \
# 0  http://cdr.eionet.europa.eu/Converters/run_con...
# 1  http://cdr.eionet.europa.eu/Converters/run_con...
# 2  http://cdr.eionet.europa.eu/Converters/run_con...
# 3  http://cdr.eionet.europa.eu/Converters/run_con...
# 4  http://cdr.eionet.europa.eu/Converters/run_con...
#
#    Status_of_implementation_clean:text Implementation_period_start_clean:text  \
# 0                          Implemented                                   2000
# 1                          Implemented                                   2000
# 2                  See individual PaMs                    See individual PaMs
# 3                              Planned                                   2015
# 4                  See individual PaMs                    See individual PaMs
#
#   Projection_scenario_in_which_the_policy_or_measure_is_included_clean:text  \
# 0                             With existing measures
# 1                             With existing measures
# 2                                See individual PaMs
# 3                           With additional measures
# 4                                See individual PaMs
#
#   Is_the_policy_or_measure_related_to_a_Union_policy__clean:text  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#           Union_policy_lookup_only4facets_clean:text  \
# 0  Other (Union policy not listed above or additi...
# 1  Other (Union policy not listed above or additi...
# 2  Effort Sharing Decision 406/2009/EC; Industria...
# 3  Energy Efficiency Directive 2012/27/EU; Recast...
# 4  Cogeneration Directive 2004/8/EC; Energy Taxat...
#
#   Projected_net_cost_per_year__EUR_:text Realised_net_cost_per_year__EUR_:text
# 0                               121204.0                                   NaN
# 1                                80803.0                                   NaN
# 2                                    NaN                                   NaN
# 3                                    NaN                                   NaN
# 4                                    NaN                                   NaN
#
# [5 rows x 76 columns]

# %%
links = eu_db['ReportID:text'].tolist()
print(len(links))
print(links[0])
# Out:
# 1323
# http://cdr.eionet.europa.eu/Converters/run_conversion?file=/ec/mmr/art04-13-14_lcds_pams_projections/colvzkuna/envvzkvxq/CZ_MMR_PAM__20150626.xml&conv=524&source=remote#pam21

# %%
description = eu_db[['Description:text']]
description['label'] = 1
description.head()
# Out:
# /Users/d/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Description:text  label
# 0  Introduction of "Park and Ride" systém,  combi...      1
# 1  To provide with information about CO2 emission...      1
# 2   Reduction of GHG emissions in Agriculture sector      1
# 3  Reduction of the energy consumption by the fol...      1
# 4       Support RES financially and tax fossil fuels      1
